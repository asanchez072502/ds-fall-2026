# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
# !pip install pandas numpy
import pandas as pd
import numpy as np
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = '/workspaces/ds-fall-2026/Week-02-Pandas-and-How-to-Make-a-Sick-Project/data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
df_food.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    str
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    str
#  8   comfort_food_reasons          123 non-null    str
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
#  12  cuisine                       108 non-null    float64
# ...

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
df_food.dtypes
# Out:
# GPA                     str
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports             str
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight                  str
# Length: 61, dtype: object

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
columns = ['calories_day', 'weight', 'Gender']
filtered_df = df_food[columns]
filtered_df
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.

filtered_df.isna().sum()
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.
clean_df = filtered_df.dropna()
clean_df.info()
clean_df
# Out:
# <class 'pandas.DataFrame'>
# Index: 104 entries, 1 to 123
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   calories_day  104 non-null    float64
#  1   weight        104 non-null    str
#  2   Gender        104 non-null    int64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 3.2 KB
#      calories_day                    weight  Gender
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# 5             3.0                       190       1
# ..            ...                       ...     ...
# 118           3.0                       140       1
# 119           3.0                       185       2
# 120           4.0                       156       1
# 121           2.0                       180       1
# ...

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.
cleaner_df = clean_df.apply(pd.to_numeric, errors='coerce')
cleaner_df.value_counts()
# Out:
# calories_day  weight  Gender
# 3.0           125.0   1         5
#               185.0   2         5
#               150.0   1         4
#               140.0   1         4
#               155.0   1         3
#                                ..
#               138.0   2         1
# 4.0           150.0   2         1
#               156.0   1         1
# 2.0           180.0   1         1
# 4.0           135.0   2         1
# Name: count, Length: 72, dtype: int64

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
filepath = "/workspaces/ds-fall-2026/Week-02-Pandas-and-How-to-Make-a-Sick-Project/data/cleaned.csv"
cleaner_df.to_csv(filepath)

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).
df_salary = pd.read_csv('/workspaces/ds-fall-2026/Week-02-Pandas-and-How-to-Make-a-Sick-Project/data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv', sep='\t')
filepath = "/workspaces/ds-fall-2026/Week-02-Pandas-and-How-to-Make-a-Sick-Project/data/salarysurvey.tsv"
df_salary.to_csv(filepath, sep='\t', index=False)

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
filepath = "/workspaces/ds-fall-2026/Week-02-Pandas-and-How-to-Make-a-Sick-Project/data/salarysurvey.tsv"
df_salary = pd.read_csv(filepath, sep='\t')
print(f"shape: {df_salary.shape}")
print(f"df_salary.info(): {df_salary.info()}")
# Out:
# shape: (28062, 18)
# <class 'pandas.DataFrame'>
# RangeIndex: 28062 entries, 0 to 28061
# Data columns (total 18 columns):
#  #   Column                                                                                                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                --------------  -----
#  0   Timestamp                                                                                                                                                                                                                             28062 non-null  str
# ...

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.

print(df_salary.dtypes)
# Out:
# Timestamp                                                                                                                                                                                                                                   str
# How old are you?                                                                                                                                                                                                                            str
# What industry do you work in?                                                                                                                                                                                                               str
# Job title                                                                                                                                                                                                                                   str
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
old_column_names = df_salary.columns.tolist()
new_column_names = ['timestamp', 'age', 'industry', 'title', 'title_context', 'salary', 'additional_compensation', 'currency', 'other_currency', 'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe', 'highest_education_completed', 'gender', 'race']
updatedNames = dict(zip(old_column_names, new_column_names))
df_new_salary = df_salary.rename(columns = updatedNames)
print(df_new_salary.head())
# Out:
#             timestamp    age                       industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                       title title_context  salary  \
# 0        Research and Instruction Librarian           NaN  55,000
# 1  Change & Internal Communications Manager           NaN  54,600
# 2                      Marketing Specialist           NaN  34,000
# 3                           Program Manager           NaN  62,000
# 4                        Accounting Manager           NaN  60,000
#
#    additional_compensation currency other_currency salary_context  \
# 0                      0.0      USD            NaN            NaN
# 1                   4000.0      GBP            NaN            NaN
# ...

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.

df_new_salary['industry'].value_counts()

# Computing or Tech
# Out:
# industry
# Computing or Tech                               4699
# Education (Higher Education)                    2464
# Nonprofits                                      2419
# Health care                                     1896
# Government and Public Administration            1889
#                                                 ...
# Undergrad student                                  1
# Concrete Construction                              1
# I'm currently a student and don't have a job       1
# Student                                            1
# Wine & Spirits                                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)
cond = df_new_salary['industry'] == 'Computing or Tech'
df_salary_tech = df_new_salary[cond].copy()
df_salary_tech
# Out:
#                 timestamp    age           industry  \
# 1      4/27/2021 11:02:22  25-34  Computing or Tech
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28050   7/1/2024 13:38:46  25-34  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                               title  \
# 1          Change & Internal Communications Manager
# 8                                   Systems Analyst
# 43                      Principal Software Engineer
# 44                             Intelligence Analyst
# 46                                 Mobile developer
# ...

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 

df_salary_tech.value_counts()
# Out:
# timestamp          age    industry           title  title_context  salary  additional_compensation  currency  other_currency  salary_context  country  state     city  total_yoe  field_yoe      highest_education_completed  gender  race
# 2/6/2024 21:15:28  18-24  Computing or Tech  sdsd   ds             4       22.0                     USD       1               dd              ss       Arkansas  s     5-7 years  11 - 20 years  Some college                 Man     Black or African American    1
# Name: count, dtype: int64

# %% [markdown]
# +3.1LLLLLL          ZxcWe are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!

cond = df_salary_tech['currency'] == 'USD'
USD_df = df_salary_tech[cond].copy()

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.

USD_df['country'].value_counts()
# Out:
# country
# United States               1576
# USA                         1222
# US                           412
# U.S.                         108
# United States of America      90
#                             ...
# Ghana                          1
# Nigeria                        1
# ss                             1
# Nigeria                        1
# Burma                          1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.

normalized_df = USD_df['country'].copy().str.strip().str.lower().str.replace(' ', '', regex=False).str.replace('\'', '', regex=False).str.replace('.', '', regex=False)
USSpellings = normalized_df.value_counts().head(4).index.to_list()
USSpellings.extend(['unitedstateofamerica', 'unitestates', 'uniyedstates', 'america', 'unitedstate', 'unitedstateds', 'unitedstated', 'unitedstares', 'unitesstates'])
normalizedMaskDF = normalized_df.isin(USSpellings)
# create a copy, incase I botch something.
normalizedUSDdf = USD_df.copy()
normalizedUSDdf['country'] = np.where(normalizedMaskDF, 'US', USD_df['country'])
normalizedUSDdf['country'].value_counts()
# Out:
# country
# US                      3723
# Israel                     5
# Canada                     4
# Australia                  2
# India                      2
# Spain                      2
# Brazil                     2
# United Kingdom             2
# New Zealand                2
# Poland                     2
# France                     2
# Puerto Rico                1
# Cuba                       1
# Danmark                    1
# Italy                      1
# International              1
# Remote (philippines)       1
# Singapore                  1
# Uruguay                    1
# Mexico                     1
# Canada                     1
# ISA                        1
# singapore                  1
# Pakistan                   1
# Netherlands                1
# China                      1
# San Francisco              1
# Romania                    1
# Japan                      1
# Australian                 1
# Denmark                    1
# ...

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
normalizedUSDdf['country'].value_counts()
# Out:
# country
# US                      3723
# Israel                     5
# Canada                     4
# Australia                  2
# India                      2
# Spain                      2
# Brazil                     2
# United Kingdom             2
# New Zealand                2
# Poland                     2
# France                     2
# Puerto Rico                1
# Cuba                       1
# Danmark                    1
# Italy                      1
# International              1
# Remote (philippines)       1
# Singapore                  1
# Uruguay                    1
# Mexico                     1
# Canada                     1
# ISA                        1
# singapore                  1
# Pakistan                   1
# Netherlands                1
# China                      1
# San Francisco              1
# Romania                    1
# Japan                      1
# Australian                 1
# Denmark                    1
# ...

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

# did it above

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

normalizedUSDdf.head(5)
# Out:
#              timestamp    age           industry                        title  \
# 8   4/27/2021 11:03:01  45-54  Computing or Tech              Systems Analyst
# 43  4/27/2021 11:04:04  25-34  Computing or Tech  Principal Software Engineer
# 44  4/27/2021 11:04:04  25-34  Computing or Tech         Intelligence Analyst
# 46  4/27/2021 11:04:07  35-44  Computing or Tech             Mobile developer
# 47  4/27/2021 11:04:09  35-44  Computing or Tech      Product Design Director
#
#                    title_context   salary  additional_compensation currency  \
# 8   Data developer/ETL Developer  112,000                  10000.0      USD
# 43                           NaN  187,500                   5000.0      USD
# 44                           NaN  110,000                  20000.0      USD
# 46                           NaN  144,600                   2500.0      USD
# 47                           NaN  200,850                  40000.0      USD
#
# ...

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.
USMask = normalizedUSDdf['country'] == 'US'

# keep only rows with 'US'
USDF = normalizedUSDdf[USMask]

# group by states
groupedStates = USDF.groupby('state')

# think this is the part where the non-numeric field bites me in the keester.
groupedStates['salary'].agg(['min', 'max', 'mean'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 11
#       8 groupedStates = USDF.groupby('state')
#      10 # think this is the part where the non-numeric field bites me in the keester.
# ---> 11 groupedStates['salary'].agg(['min', 'max', 'mean'])
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/groupby/generic.py:464, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     462 kwargs["engine"] = engine
#     463 kwargs["engine_kwargs"] = engine_kwargs
# --> 464 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     465 if relabeling:
#     466     # columns is not narrowed by mypy from relabeling flag
#     467     assert columns is not None  # for mypy
#
# ...

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.
normalizedSalary = USDF['salary'].str.replace(',', '', regex=False)
numericUSDF = USDF.copy()
numericUSDF['salary'] = pd.to_numeric(normalizedSalary, errors='coerce')
numericUSDF['salary'].value_counts()
# Out:
# salary
# 120000     95
# 130000     94
# 150000     86
# 110000     85
# 90000      77
#            ..
# 170420      1
# 45109       1
# 116421      1
# 101150      1
# 2600000     1
# Name: count, Length: 686, dtype: int64

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!

USMask = numericUSDF['country'] == 'US'
USOnlyDF = numericUSDF[USMask]

aggResults = USOnlyDF.groupby('state')['salary'].agg(['min', 'mean', 'max'])
aggResults.sort_values('mean', ascending=False)
# Out:
#                                 min           mean      max
# state
# Michigan, Texas, Washington  340000  340000.000000   340000
# California, Oregon           200000  200000.000000   200000
# California, Colorado         176000  176000.000000   176000
# Georgia, Massachusetts       175000  175000.000000   175000
# Florida                       28800  157457.232143  2600000
# ...                             ...            ...      ...
# Louisiana                     35360   83269.090909   150000
# Massachusetts, Pennsylvania   83000   83000.000000    83000
# Arkansas                      55000   81682.300000   144000
# California, Maryland          81500   81500.000000    81500
# Alabama, Montana              72000   72000.000000    72000
#
# [66 rows x 3 columns]

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.

datedDF = USOnlyDF.copy()
datedDF['timestamp'] = pd.to_datetime(datedDF['timestamp'])
yearMask = datedDF['timestamp'].dt.year.isin([2021,2022])
datedDF = datedDF[yearMask]
datedDF['timestamp'].dt.year.value_counts()
# Out:
# timestamp
# 2021    3663
# 2022      39
# Name: count, dtype: int64

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
